# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat2017File = '../data/sat_2017.csv'
sat2017 = pd.read_csv(sat2017File)
act2017File = '../data/act_2017.csv'
act2017 = pd.read_csv(act2017File)

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
# Preliminary check of SAT data
sat2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# Preliminary check of ACT data
act2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# ## 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# In the SAT file, it shows all the states in the US and the average scores for each section as well as the average total score for each state. It also tells us the participitation rate of the state, meaning how many students/schools participated in the state.
#
# For the SAT file, we can see that the minimum value is 482 for reading and writing, 468 for math, however the total minimum score is 950. The maximum scores are 644 for reading and writing, 651 for math and the total has 1295.
#
# In the ACT file, it shows all the states in the US and the average scores for each section as well as the average total score for each state. It also tells us the participitation rate of the state, meaning how many students/schools participated in the state. Unlike the SAT, the ACT file also gives the national averages
#
# For the ACT file, we can see that the minimum value is 16.3 for english, 18 for math, 18.1 for reading, and 2.3 for science. The composite score is of string type at the moment and cannot find specific values at this point. The maximum scores are 25.5 for english, 25.3 for math, 26 for reading, and 24.9 for science.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
# Yes, there are no NaN or null values in the table. It seems that all states have submitted some kind of data for the file, how accurate the data actually is is different.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
# Checking the top 10 states with best SAT scores
sat2017.sort_values(by = 'Total').head(10)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
# 19                 Maine           95%                                 513
# 9                Florida           83%                                 520
# 43                 Texas           62%                                 513
# 6            Connecticut          100%                                 530
# 36              Oklahoma            7%                                 530
# 10               Georgia           61%                                 535
#
#     Math  Total
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005
# 19   499   1012
# 9    497   1017
# 43   507   1020
# ...

# %%
# Checking the top 1- states with best ACT scores
act2017.sort_values(by = 'Composite').head(10)
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 12          Hawaii           90%     17.8  19.2     19.2     19.3      19.0
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1
# 1          Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 4         Arkansas          100%     18.9  19.0     19.7     19.5      19.4
# 37        Oklahoma          100%     18.5  18.8     20.1     19.6      19.4
# 19       Louisiana          100%     19.4  18.8     19.8     19.6      19.5
# 3          Arizona           62%     18.6  19.8     20.1     19.8      19.7

# %% [markdown]
# Answer:
# The total minimum score for the SAT is 400, 200 for the Reading and Writing section, and 200 for the math section. The maximum score is 1600 total, 800 for the reading/english and 800 for the math section.
#
# In the SAT file, currently Maryland shows that their average math score if 52, which is not a score that could be allowed. When you subtract the total score from the reading and writing section, the math score should be 524. It seems that maybe the '4' digit was left out during the data entry phase.
#
# For the ACT, each section will be scored between 1-36. The composite score will be the average of the sum of all the scores, and will also be represented by a value between 1-36.
#
# For Wyoming, the composite score has a x at the end of its number. Unless there is a specific reason for it, it might just be a typo during the data entry phase.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
sat2017.loc[20,'Math'] = 524

# %%
act2017.loc[51, 'Composite'] = 20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# Checking data types of features for SAT dataset
sat2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Checking data types of features for ACT dataset
act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# Participation for both can be used as either int/float, but since it has the '%' sign, it becomes a string type.
#
# The composite score for the ACT file should be a float instead of an object.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# Changing participation from object type to int type
sat2017['Participation'] = sat2017['Participation'].map(lambda partCell: int(partCell[:-1]))
act2017['Participation'] = act2017['Participation'].map(lambda partCell: int(partCell[:-1]))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Changing composite score to float type
act2017['Composite'] = act2017['Composite'].map(lambda compCell: float(compCell))

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# Checking dtypes after change
print(sat2017['Participation'].dtype)
print(act2017['Participation'].dtype)
print(act2017['Composite'].dtype)
# Out:
# int64
# int64
# float64

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
# Double checking that whole SAT dataset is correct
sat2017.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Double checking that the whole ACT dataset is correct
act2017.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
# Renaming column names
sat2017.columns = ['states', 'sat_participation_17_(%)', 'sat_reading_and_writing_17', 'sat_math_17', 'sat_totals_17']
act2017.columns = ['states', 'act_participation_17_(%)', 'act_english_17', 'act_math_17', 'act_reading_17', 'act_science_17', 'act_composite_17']

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |states|Object|ACT/SAT|Name of the states listed in both datasets|
# |sat_participation|Int|SAT|The participation rate for each state (units are presented in %)
# |act_participation|Int|ACT|The participation rate for each state (units are presented in %)
# |sat_reading_and_writing|Int|SAT|The average scores per state for the SAT reading and writing section (represents average scores)
# |sat_math|Int|SAT|The average scores per state for the SAT math section (represents average scores)
# |sat_totals|Int|SAT|The average total scores per state for the SAT (represents average scores)
# |act_english|float|ACT|The average scores per state for the ACT english section (represents average scores)
# |act_math|float|ACT|The average scores per state for the ACT math section (represents average scores)
# |act_reading|float|ACT|The average scores per state for the ACT reading section (represents average scores)
# |act_science|float|ACT|The average scores per state for the ACT science section (represents average scores)
# |act_composite|float|ACT|The average composite scores per state for the ACT (represents average scores)

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Removing first row
act2017.drop([0]).head()
# Out:
#        states  act_participation_17_(%)  act_english_17  act_math_17  \
# 1     Alabama                       100            18.9         18.4
# 2      Alaska                        65            18.7         19.8
# 3     Arizona                        62            18.6         19.8
# 4    Arkansas                       100            18.9         19.0
# 5  California                        31            22.5         22.7
#
#    act_reading_17  act_science_17  act_composite_17
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4
# 5            23.1            22.2              22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# Merging on states
combined_2017 = sat2017.merge(act2017, left_on='states', right_on='states')

# %%
combined_2017.sort_values('sat_totals_17', ascending = False).head()
# Out:
#        states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 23  Minnesota                         3                         644
# 49  Wisconsin                         3                         642
# 15       Iowa                         2                         641
# 25   Missouri                         3                         640
# 16     Kansas                         4                         632
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 23          651           1295                       100            20.4
# 49          649           1291                       100            19.7
# 15          635           1275                        67            21.2
# 25          631           1271                       100            19.8
# 16          628           1260                        73            21.1
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('combined_2017', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat2018 = pd.read_csv('../data/SAT2018_Testing _Data - SAT 2018.csv')

# %%
act2018 = pd.read_csv('../data/SAT2018_Testing _Data - ACT 2018.csv')

# %%
# Checking that it got imported correctly
sat2018.head()
# Out:
#           State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Minnesota            4%                                 643   655   1298
# 1     Wisconsin            3%                                 641   653   1294
# 2  North Dakota            2%                                 640   643   1283
# 3          Iowa            3%                                 634   631   1265
# 4        Kansas            4%                                 633   631   1265

# %%
# Checking that it got imported correctly
act2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Checking the datatypes of each column for SAT 2018 
sat2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Checking the datatypes of each column for ACT 2018
act2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %% [markdown]
# The data for 2018 is very similar to the data in 2017. The only major difference is that for the ACT file, the only columns that exist, aside from state and patricipation, is the composite. It doesn't offer data for individual section breakdowns. The data for both files are also not organized alphabetically by state either.

# %%
# mispelled states are mississippi, and oklahoma
sat2018.sort_values('Participation', ascending = False)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 41              Illinois           99%                                 513
# 43                 Maine           99%                                 512
# 42          Rhode Island           97%                                 513
# 36         New Hampshire           96%                                 535
# 50  District of Columbia           92%                                 497
# 26            New Jersey           82%                                 547
# 18         Massachusetts           80%                                 562
# 37             Oaklahoma            8%                                 541
# 34              New York           79%                                 534
# 30              Maryland           76%                                 545
# 35               Georgia           70%                                 542
# ...

# %%
# mispelled states are washington DC, 
# national also exists
act2018.sort_values('State')
# Out:
#                State Participation  Composite
# 0            Alabama          100%       19.1
# 1             Alaska           33%       20.8
# 2            Arizona           66%       19.2
# 3           Arkansas          100%       19.4
# 4         California           27%       22.7
# 5           Colorado           30%       23.9
# 6        Connecticut           26%       25.6
# 7           Delaware           17%       23.8
# 9            Florida           66%       19.9
# 10           Georgia           53%       21.4
# 11            Hawaii           89%       18.9
# 12             Idaho           36%       22.3
# 13          Illinois           43%       23.9
# 14           Indiana           32%       22.5
# 15              Iowa           68%       21.8
# 16            Kansas           71%       21.6
# 17          Kentucky          100%       20.2
# 18         Louisiana          100%       19.2
# 19             Maine            7%       24.0
# ...

# %%
# Like the 2017 files, the participation are strings, so they would need to be changed to int type
sat2018['Participation'] = sat2018['Participation'].map(lambda partCell: int(partCell[:-1]))
act2018['Participation'] = act2018['Participation'].map(lambda partCell: int(partCell[:-1]))

# %%
# Checking if participation has been changed correctly
sat2018.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act2018.dtypes
# Out:
# State             object
# Participation      int64
# Composite        float64
# dtype: object

# %%
# Correcting the misspelled states in both files
sat2018.loc[8, 'State'] = 'Mississippi'
sat2018.loc[37, 'State'] = 'Oklahoma'
act2018.loc[8, 'State'] = 'District of Columbia'

# %%
# Removing nationals from ACT dataframe
act2018.drop([51]);;
# Out:
#                    State  Participation  Composite
# 0                Alabama            100       19.1
# 1                 Alaska             33       20.8
# 2                Arizona             66       19.2
# 3               Arkansas            100       19.4
# 4             California             27       22.7
# 5               Colorado             30       23.9
# 6            Connecticut             26       25.6
# 7               Delaware             17       23.8
# 8   District of Columbia             32       23.6
# 9                Florida             66       19.9
# 10               Georgia             53       21.4
# 11                Hawaii             89       18.9
# 12                 Idaho             36       22.3
# 13              Illinois             43       23.9
# 14               Indiana             32       22.5
# 15                  Iowa             68       21.8
# 16                Kansas             71       21.6
# ...

# %%
# Changing the names for both the files
sat2018.columns = ['states', 'sat_participation_18_(%)', 'sat_reading_and_writing_18', 'sat_math_18', 'sat_totals_18']
act2018.columns = ['states', 'act_participation_18_(%)', 'act_composite_18']

# %%
# Check SAT 2018 dataframe to check if the data and column names are correct
sat2018.head()
# Out:
#          states  sat_participation_18_(%)  sat_reading_and_writing_18  \
# 0     Minnesota                         4                         643
# 1     Wisconsin                         3                         641
# 2  North Dakota                         2                         640
# 3          Iowa                         3                         634
# 4        Kansas                         4                         633
#
#    sat_math_18  sat_totals_18
# 0          655           1298
# 1          653           1294
# 2          643           1283
# 3          631           1265
# 4          631           1265

# %%
# Check ACT 2018 dataframe to check if the data and column names are correct
act2018.head()
# Out:
#        states  act_participation_18_(%)  act_composite_18
# 0     Alabama                       100              19.1
# 1      Alaska                        33              20.8
# 2     Arizona                        66              19.2
# 3    Arkansas                       100              19.4
# 4  California                        27              22.7

# %%
# Combining both dataframes by state
sat2018 = sat2018.sort_values('states')
combined_2018 = sat2018.merge(act2018, left_on='states', right_on='states')

# %%
# Checking to see if combining them worked
combined_2018.head()
# Out:
#        states  sat_participation_18_(%)  sat_reading_and_writing_18  \
# 0     Alabama                         6                         595
# 1      Alaska                        43                         562
# 2     Arizona                        29                         577
# 3    Arkansas                         5                         592
# 4  California                        60                         540
#
#    sat_math_18  sat_totals_18  act_participation_18_(%)  act_composite_18
# 0          571           1166                       100              19.1
# 1          544           1106                        33              20.8
# 2          572           1149                        66              19.2
# 3          576           1169                       100              19.4
# 4          536           1076                        27              22.7

# %%
# Looking at data from a SAT participation point of view
combined_2018.sort_values('sat_participation_18_(%)', ascending = False).head()
# Out:
#          states  sat_participation_18_(%)  sat_reading_and_writing_18  \
# 12        Idaho                       100                         508
# 5      Colorado                       100                         519
# 6   Connecticut                       100                         535
# 7      Delaware                       100                         505
# 21     Michigan                       100                         511
#
#     sat_math_18  sat_totals_18  act_participation_18_(%)  act_composite_18
# 12          493           1001                        36              22.3
# 5           506           1025                        30              23.9
# 6           519           1053                        26              25.6
# 7           492            998                        17              23.8
# 21          499           1011                        22              24.2

# %%
# Creating new CSV file for combined 2018 dataframe
combined_2018.to_csv('combined_2018', index=False)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = combined_2017.merge(combined_2018, left_on='states', right_on='states')

# %%
# Checking if final had merged correctly
final.head()
# Out:
#        states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 0     Alabama                         5                         593
# 1      Alaska                        38                         547
# 2     Arizona                        30                         563
# 3    Arkansas                         3                         614
# 4  California                        53                         531
#
#    sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 0          572           1165                       100            18.9
# 1          533           1080                        65            18.7
# 2          553           1116                        62            18.6
# 3          594           1208                       100            18.9
# 4          524           1055                        31            22.5
#
#    act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
final.to_csv('final', index = False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                             count      mean        std    min       25%  \
# sat_participation_17_(%)     50.0    40.520  35.258370    2.0     4.250
# sat_reading_and_writing_17   50.0   567.880  45.258279  482.0   532.750
# sat_math_17                  50.0   555.700  46.829369  468.0   523.250
# sat_totals_17                50.0  1123.680  91.791120  950.0  1055.250
# act_participation_17_(%)     50.0    64.560  32.077814    8.0    31.000
# act_english_17               50.0    20.958   2.369801   16.3    19.000
# act_math_17                  50.0    21.218   1.985528   18.0    19.500
# act_reading_17               50.0    22.044   2.076807   18.1    20.425
# act_science_17               50.0    21.060   3.211904    2.3    19.900
# act_composite_17             50.0    21.550   2.029401   17.8    19.800
# sat_participation_18_(%)     50.0    46.600  37.185141    2.0     5.250
# sat_reading_and_writing_18   50.0   562.360  47.021385  480.0   534.250
# ...

# %%
np.std(final['sat_participation_17_(%)'])
# Out:
# 34.90400550080176

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def stdCalc(data, column):
    columnMean = data[column].mean()
    tempTotal = 0
    std = 0
    for i in range(len(final)):
        tempTotal += ((final[column][i] - columnMean) ** 2)
    std = ((1/((len(final))))*tempTotal)**0.5
    return std

# %%
# Check to see if function works on its own
stdCalc(final, 'sat_participation_17_(%)')
# Out:
# 34.90400550080176

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
sd = {k:stdCalc(final, k) for k in list(final) if final[k].dtype == 'float64' or final[k].dtype == 'int64' }

# %%
# Checking that std deviation calculation worked
sd
# Out:
# {'sat_participation_17_(%)': 34.90400550080176,
#  'sat_reading_and_writing_17': 44.80341058446332,
#  'sat_math_17': 46.35871007696396,
#  'sat_totals_17': 90.86857322529059,
#  'act_participation_17_(%)': 31.755415286215364,
#  'act_english_17': 2.34598294963966,
#  'act_math_17': 1.9655726900829693,
#  'act_reading_17': 2.0559338510759533,
#  'act_science_17': 3.179622619116929,
#  'act_composite_17': 2.0090047287151913,
#  'sat_participation_18_(%)': 36.81141127422311,
#  'sat_reading_and_writing_18': 46.54879590279431,
#  'sat_math_18': 47.24089753592748,
#  'sat_totals_18': 92.68640677035657,
#  'act_participation_18_(%)': 33.595213944846364,
#  'act_composite_18': 2.1034533510396667}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# The manual calculation does not match up with the describe method, however it does match up with numpy's std method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code
#checking for the lowest participation rates for SAT in 2017
final.sort_values('sat_participation_17_(%)').head()
# Out:
#           states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 33  North Dakota                         2                         635
# 23   Mississippi                         2                         634
# 15          Iowa                         2                         641
# 24      Missouri                         3                         640
# 43          Utah                         3                         624
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 33          621           1256                        98            19.0
# 23          607           1242                       100            18.2
# 15          635           1275                        67            21.2
# 24          631           1271                       100            19.8
# 43          614           1238                       100            19.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for highest participation rates for SAT in 2017
final.sort_values('sat_participation_17_(%)', ascending = False).head()
# Out:
#                   states  sat_participation_17_(%)  \
# 21              Michigan                       100
# 6            Connecticut                       100
# 7               Delaware                       100
# 8   District of Columbia                       100
# 28         New Hampshire                        96
#
#     sat_reading_and_writing_17  sat_math_17  sat_totals_17  \
# 21                         509          495           1005
# 6                          530          512           1041
# 7                          503          492            996
# 8                          482          468            950
# 28                         532          520           1052
#
#     act_participation_17_(%)  act_english_17  act_math_17  act_reading_17  \
# 21                        29            24.1         23.7            24.5
# 6                         31            25.5         24.6            25.6
# ...

# %%
#checking for the lowest participation rates for SAT in 2018
final.sort_values('sat_participation_18_(%)').head()
# Out:
#           states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 33  North Dakota                         2                         635
# 49       Wyoming                         3                         626
# 40  South Dakota                         3                         612
# 26      Nebraska                         3                         629
# 48     Wisconsin                         3                         642
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 33          621           1256                        98            19.0
# 49          604           1230                       100            19.4
# 40          603           1216                        80            20.7
# 26          625           1253                        84            20.9
# 48          649           1291                       100            19.7
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for highest participation rates for SAT in 2018
final.sort_values('sat_participation_18_(%)', ascending = False).head()
# Out:
#          states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 12        Idaho                        93                         513
# 5      Colorado                        11                         606
# 6   Connecticut                       100                         530
# 7      Delaware                       100                         503
# 21     Michigan                       100                         509
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 12          493           1005                        38            21.9
# 5           595           1201                       100            20.1
# 6           512           1041                        31            25.5
# 7           492            996                        18            24.1
# 21          495           1005                        29            24.1
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for lower participation rates for ACT in 2017
final.sort_values('act_participation_17_(%)').head()
# Out:
#            states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 18          Maine                        95                         513
# 28  New Hampshire                        96                         532
# 7        Delaware                       100                         503
# 38   Rhode Island                        71                         539
# 37   Pennsylvania                        65                         540
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 18          499           1012                         8            24.2
# 28          520           1052                        18            25.4
# 7           492            996                        18            24.1
# 38          524           1062                        21            24.0
# 37          531           1071                        23            23.4
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for highest participation rates for ACT in 2017
final.sort_values('act_participation_17_(%)', ascending = False).head()
# Out:
#        states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 0     Alabama                         5                         593
# 17  Louisiana                         4                         611
# 48  Wisconsin                         3                         642
# 43       Utah                         3                         624
# 41  Tennessee                         5                         623
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 0           572           1165                       100            18.9
# 17          586           1198                       100            19.4
# 48          649           1291                       100            19.7
# 43          614           1238                       100            19.5
# 41          604           1228                       100            19.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for lower participation rates for ACT in 2018
final.sort_values('act_participation_18_(%)').head()
# Out:
#            states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 18          Maine                        95                         513
# 38   Rhode Island                        71                         539
# 28  New Hampshire                        96                         532
# 7        Delaware                       100                         503
# 37   Pennsylvania                        65                         540
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 18          499           1012                         8            24.2
# 38          524           1062                        21            24.0
# 28          520           1052                        18            25.4
# 7           492            996                        18            24.1
# 37          531           1071                        23            23.4
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for highest participation rates for ACT in 2018
final.sort_values('act_participation_18_(%)', ascending = False).head()
# Out:
#        states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 0     Alabama                         5                         593
# 17  Louisiana                         4                         611
# 48  Wisconsin                         3                         642
# 43       Utah                         3                         624
# 41  Tennessee                         5                         623
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 0           572           1165                       100            18.9
# 17          586           1198                       100            19.4
# 48          649           1291                       100            19.7
# 43          614           1238                       100            19.5
# 41          604           1228                       100            19.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for lowest SAT total score for 2017
final.sort_values('sat_totals_17').head()
# Out:
#                   states  sat_participation_17_(%)  \
# 8   District of Columbia                       100
# 7               Delaware                       100
# 12                 Idaho                        93
# 21              Michigan                       100
# 18                 Maine                        95
#
#     sat_reading_and_writing_17  sat_math_17  sat_totals_17  \
# 8                          482          468            950
# 7                          503          492            996
# 12                         513          493           1005
# 21                         509          495           1005
# 18                         513          499           1012
#
#     act_participation_17_(%)  act_english_17  act_math_17  act_reading_17  \
# 8                         32            24.4         23.5            24.9
# 7                         18            24.1         23.4            24.8
# ...

# %%
# checking for highest SAT total score for 2017
final.sort_values('sat_totals_17', ascending = False).head()
# Out:
#        states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 22  Minnesota                         3                         644
# 48  Wisconsin                         3                         642
# 15       Iowa                         2                         641
# 24   Missouri                         3                         640
# 16     Kansas                         4                         632
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 22          651           1295                       100            20.4
# 48          649           1291                       100            19.7
# 15          635           1275                        67            21.2
# 24          631           1271                       100            19.8
# 16          628           1260                        73            21.1
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for lowest SAT total score for 2018
final.sort_values('sat_totals_18').head()
# Out:
#                   states  sat_participation_17_(%)  \
# 8   District of Columbia                       100
# 7               Delaware                       100
# 47         West Virginia                        14
# 12                 Idaho                        93
# 43                  Utah                         3
#
#     sat_reading_and_writing_17  sat_math_17  sat_totals_17  \
# 8                          482          468            950
# 7                          503          492            996
# 47                         558          528           1086
# 12                         513          493           1005
# 43                         624          614           1238
#
#     act_participation_17_(%)  act_english_17  act_math_17  act_reading_17  \
# 8                         32            24.4         23.5            24.9
# 7                         18            24.1         23.4            24.8
# ...

# %%
# checking for highest SAT total score for 2018
final.sort_values('sat_totals_18', ascending = False).head()
# Out:
#           states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 22     Minnesota                         3                         644
# 48     Wisconsin                         3                         642
# 33  North Dakota                         2                         635
# 15          Iowa                         2                         641
# 16        Kansas                         4                         632
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 22          651           1295                       100            20.4
# 48          649           1291                       100            19.7
# 33          621           1256                        98            19.0
# 15          635           1275                        67            21.2
# 16          628           1260                        73            21.1
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for lowest ACT composite score for 2017
final.sort_values('act_composite_17').head()
# Out:
#             states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 27          Nevada                        26                         563
# 23     Mississippi                         2                         634
# 39  South Carolina                        50                         543
# 11          Hawaii                        55                         544
# 32  North Carolina                        49                         546
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 27          553           1116                       100            16.3
# 23          607           1242                       100            18.2
# 39          521           1064                       100            17.5
# 11          541           1085                        90            17.8
# 32          535           1081                       100            17.8
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for highest ACT composite score for 2017
final.sort_values('act_composite_17', ascending = False).head()
# Out:
#                   states  sat_participation_17_(%)  \
# 28         New Hampshire                        96
# 20         Massachusetts                        76
# 6            Connecticut                       100
# 18                 Maine                        95
# 8   District of Columbia                       100
#
#     sat_reading_and_writing_17  sat_math_17  sat_totals_17  \
# 28                         532          520           1052
# 20                         555          551           1107
# 6                          530          512           1041
# 18                         513          499           1012
# 8                          482          468            950
#
#     act_participation_17_(%)  act_english_17  act_math_17  act_reading_17  \
# 28                        18            25.4         25.1            26.0
# 20                        29            25.4         25.3            25.9
# ...

# %%
# checking for lowest ACT composite score for 2018
final.sort_values('act_composite_18').head()
# Out:
#             states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 27          Nevada                        26                         563
# 39  South Carolina                        50                         543
# 23     Mississippi                         2                         634
# 11          Hawaii                        55                         544
# 0          Alabama                         5                         593
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 27          553           1116                       100            16.3
# 39          521           1064                       100            17.5
# 23          607           1242                       100            18.2
# 11          541           1085                        90            17.8
# 0           572           1165                       100            18.9
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
# checking for highest ACT composite score for 2018
final.sort_values('act_composite_18', ascending = False).head()
# Out:
#            states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 6     Connecticut                       100                         530
# 20  Massachusetts                        76                         555
# 28  New Hampshire                        96                         532
# 31       New York                        67                         528
# 38   Rhode Island                        71                         539
#
#     sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 6           512           1041                        31            25.5
# 20          551           1107                        29            25.4
# 28          520           1052                        18            25.4
# 31          523           1052                        31            23.8
# 38          524           1062                        21            24.0
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(10, 10))
plt.title('SAT and ACT Correlation Map')
sns.heatmap(final.corr(), cmap = 'YlGnBu')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (18,15)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], edgecolor='black', linewidth=1) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %%
# Checking to see if subplot_histograms works
newList = ['sat_participation_17_(%)', 'sat_reading_and_writing_17', 'sat_math_17', 'sat_totals_17']
secondList = ['Participation', 'Reading and Writing', 'Math', 'Total']
subplot_histograms(final, newList, secondList, newList)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code for plotting participation rates for SAT and ACT
plotList = ['sat_participation_17_(%)', 'sat_participation_18_(%)', 'act_participation_17_(%)', 'act_participation_18_(%)']
titleList = ['SAT Participation in 2017', 'SAT Participation in 2018', 'ACT Participation in 2017', 'ACT Participation in 2018']
xlabelList = ['Participation Percetage', 'Participation Percetage', 'Participation Percetage', 'Participation Percetage']
subplot_histograms(final, plotList, titleList, xlabelList)

# %%
# Code for plotting math scores for available years
plotList = ['sat_math_17', 'sat_math_18', 'act_math_17']
titleList = ['SAT Math Scores in 2017', 'SAT Math Scores in 2018', 'ACT Math Scores in 2017']
xlabelList = ['Math Scores', 'Math Scores', 'Math Scores']
subplot_histograms(final, plotList, titleList, xlabelList)

# %%
# Code for plotting reading/writing scores for available years
plotList = ['sat_reading_and_writing_17', 'sat_reading_and_writing_18', 'act_english_17']
titleList = ['SAT Reading and Writing Scores in 2017', 'SAT Reading and Writing Scores in 2018', 'ACT English Scores in 2017']
xlabelList = ['Reading and Writing Scores', 'Reading and Writing Scores', 'English Scores']
subplot_histograms(final, plotList, titleList, xlabelList)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
from numpy.polynomial.polynomial import polyfit
def subplot_scatterplot(dataframe, column1, column2, title, xlabel, ylabel):
    fig, ax = plt.subplots(figsize = (20, 10))
    ax.grid(color = 'gray', linewidth=0.2)
    ax.scatter(dataframe[column1], dataframe[column2])
    ax.set_title(title, fontsize = 25)
    ax.set_xlabel(xlabel, fontsize = 20)
    ax.set_ylabel(ylabel, fontsize = 20)
    x = dataframe[column1]
    y = dataframe[column2]
    b, m = polyfit(x, y, 1)
    plt.plot(x, b + m * x, '-')

# %%
# Code for comparing math scores 2017
columnList1 = ['sat_math_17', 'sat_reading_and_writing_17', 'sat_totals_17']
columnList2 = ['act_math_17', 'act_english_17', 'act_composite_17']
titleLabels = ['SAT Math vs ACT Math 2017', 'SAT Reading and Writing vs ACT English 2017', 'SAT Totals vs ACT Totals 2017']
xLabels = ['2017 SAT Math Scores', '2017 SAT Reading and Writing Scores', '2017 SAT Total Scores']
yLabels = ['2017 ACT Math Scores', '2017 ACT English Scores', '2017 ACT Composite Scores']
subplot_scatterplot(final, 'sat_math_17', 'act_math_17', 'SAT Math vs ACT Math 2017', '2017 SAT Math Scores', '2017 ACT Math Scores')

# %%
# Code for comparing sat reading and writing vs act english
subplot_scatterplot(final, 'sat_reading_and_writing_17', 'act_english_17', 'SAT Reading and Writing vs ACT English 2017', '2017 SAT Reading and Writing Scores', '2017 ACT English Scores')

# %%
# Code for comparing SAT total vs ACT composite
subplot_scatterplot(final, 'sat_totals_18', 'act_composite_18', 'SAT Total Score vs ACT Total Score (2018)', '2018 SAT Total Scores', '2018 ACT Composite')

# %%
# Code for comparing SAT total vs ACT composite
subplot_scatterplot(final, 'sat_totals_17', 'act_composite_17', 'SAT Total Score vs ACT Total Score (2017)', '2017 SAT Total Scores', '2017 ACT Composite')

# %%
# Code for comparing SAT total scores for 2017 and 2018
subplot_scatterplot(final, 'sat_totals_17', 'sat_totals_18', 'SAT Total Score 2017 vs 2018', '2017 SAT Total Scores', '2018 SAT Total Scores')

# %%
# Code for comparing ACT Composite scores for 2017 and 2018
subplot_scatterplot(final, 'act_composite_17', 'act_composite_18', 'ACT Composite Score 2017 vs 2018', '2017 ACT Composite Scores', '2018 ACT Composite Scores')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
def subplot_boxplot(dataframe, column1, title, xlabel, ylabel, xTicks):
    fig, ax = plt.subplots(figsize = (20, 10))
    ax.grid(color = 'gray', linewidth=0.2)
    ax.set_title(title, fontsize = 25)
    ax.boxplot([dataframe[column1[0]], dataframe[column1[1]], dataframe[column1[2]], dataframe[column1[3]]])
    plt.xticks([1, 2, 3, 4],[xTicks[0],xTicks[1],[xTicks[2]],[xTicks[3]]])
    ax.set_xlabel(xlabel, fontsize = 20)
    ax.set_ylabel(ylabel, fontsize = 20)

# %%
columns = ['sat_participation_17_(%)', 'sat_participation_18_(%)', 'act_participation_17_(%)', 'act_participation_18_(%)']
title = 'SAT/ACT Participation Rates by Year'
xLabel = 'Test/Years'
yLabel = 'SAT/ACT Participation Rates'
xTicks = ['SAT 2017', 'SAT 2018', 'ACT 2017', 'ACT 2018']
subplot_boxplot(final, columns, title, xLabel, yLabel, xTicks)

# %%
def subplot_boxplot2(dataframe, column1, title, xlabel, ylabel, xTicks):
    fig, ax = plt.subplots(figsize = (20, 10))
    ax.grid(color = 'gray', linewidth=0.2)
    ax.set_title(title, fontsize = 25)
    ax.boxplot([dataframe[column1[0]], dataframe[column1[1]]])
    plt.xticks([1, 2],[xTicks[0],xTicks[1]])
    ax.set_xlabel(xlabel, fontsize = 20)
    ax.set_ylabel(ylabel, fontsize = 20)

# %%
columns2 = ['sat_totals_17', 'sat_totals_18']
title = 'SAT Total Scores by Year'
xLabel = 'Years'
yLabel = 'Total Scores'
xTicks = ['SAT Total 2017', 'SAT Total 2018']
subplot_boxplot2(final, columns2, title, xLabel, yLabel, xTicks)

# %%
columns3 = ['act_composite_17', 'act_composite_18']
title = 'ACT Composite Scores by Year'
xLabel = 'Years'
yLabel = 'Composite Scores'
xTicks = ['ACT Composite 2017', 'ACT Composite 2018']
subplot_boxplot2(final, columns3, title, xLabel, yLabel, xTicks)

# %%
columns4 = ['sat_math_17', 'sat_math_18', 'sat_reading_and_writing_17', 'sat_reading_and_writing_18']
title = 'Individual SAT Scores by Year'
xLabel = 'Years'
yLabel = 'Math Scores'
xTicks = ['SAT Math 17', 'SAT Math 18', 'SAT Reading and Writing 17', 'SAT Reading and Writing 18']
subplot_boxplot(final, columns4, title, xLabel, yLabel, xTicks)

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Code for comparing SAT and ACT participation
subplot_scatterplot(final, 'sat_participation_17_(%)', 'act_participation_17_(%)', '2017 SAT Participation vs ACT Participation Rate', '2017 SAT Participation (%)', '2017 ACT Participation (%)')

# %%
subplot_scatterplot(final, 'sat_participation_18_(%)', 'act_participation_18_(%)', '2018 SAT Participation vs ACT Participation Rate', '2018 SAT Participation (%)', '2018 ACT Participation (%)')

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
final.describe().T
# Out:
#                             count      mean        std    min       25%  \
# sat_participation_17_(%)     50.0    40.520  35.258370    2.0     4.250
# sat_reading_and_writing_17   50.0   567.880  45.258279  482.0   532.750
# sat_math_17                  50.0   555.700  46.829369  468.0   523.250
# sat_totals_17                50.0  1123.680  91.791120  950.0  1055.250
# act_participation_17_(%)     50.0    64.560  32.077814    8.0    31.000
# act_english_17               50.0    20.958   2.369801   16.3    19.000
# act_math_17                  50.0    21.218   1.985528   18.0    19.500
# act_reading_17               50.0    22.044   2.076807   18.1    20.425
# act_science_17               50.0    21.060   3.211904    2.3    19.900
# act_composite_17             50.0    21.550   2.029401   17.8    19.800
# sat_participation_18_(%)     50.0    46.600  37.185141    2.0     5.250
# sat_reading_and_writing_18   50.0   562.360  47.021385  480.0   534.250
# ...

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# SAT Participation Rate: Between 2017 and 2018, participation rates for the SAT had actually increased about 5.5%. The increase in participation rate was most likely due to a few factors:
# 1. Colorado sbusidizing the SAT for students.
# 2. Since it was the second year after returning to the 1600 system, students felt more confident.
#
# ACT Participation Rate: Majority of the nation participated in the ACTs, with a rate of 64% in 2017 and a 60% participation rate in 2018. This is due to the fact that a lot of states had contracts with the ACT organizations to teach ACT curriculum.
#
# SAT Scores: Between the two years there was not a large difference in SAT scores. With a higher participation rate, the average SAT score dropped about 6 points. But with a larger population taking the SAT score, the average did not change significantly.
#
# ACT Scores: Even though there was a drop in participation for the ACT, the total composite score remained more or less unchanged between 2017 and 2018.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %%
# Checking if SAT 2017 math scores have a normal distribution
sns.distplot(final['sat_math_17'], bins = 10)

# %%
# Checking if SAT 2017 reading and writing scores have a normal distribution
sns.distplot(final['sat_reading_and_writing_17'], bins = 10)

# %%
# Checking if SAT 2017 total scores have a normal distribution
sns.distplot(final['sat_participation_17_(%)'], bins = 10)

# %%
# Checking if SAT 2018 math scores have a normal distribution
sns.distplot(final['sat_math_18'], bins = 10)

# %%
# Checking if SAT 2018 reading and writing scores have a normal distribution
sns.distplot(final['sat_reading_and_writing_18'], bins = 10)

# %%
# Checking if SAT 2018 total scores have a normal distribution
sns.distplot(final['sat_participation_18_(%)'], bins = 10)

# %%
# Checking if ACT 2017 reading scores have a normal distribution
sns.distplot(final['act_reading_17'], bins = 10)

# %%
# Checking if ACT 2017 math scores have a normal distribution
sns.distplot(final['act_math_17'], bins = 10)

# %%
# Checking to see that final dataset is complete
final.head()
# Out:
#        states  sat_participation_17_(%)  sat_reading_and_writing_17  \
# 0     Alabama                         5                         593
# 1      Alaska                        38                         547
# 2     Arizona                        30                         563
# 3    Arkansas                         3                         614
# 4  California                        53                         531
#
#    sat_math_17  sat_totals_17  act_participation_17_(%)  act_english_17  \
# 0          572           1165                       100            18.9
# 1          533           1080                        65            18.7
# 2          553           1116                        62            18.6
# 3          594           1208                       100            18.9
# 4          524           1055                        31            22.5
#
#    act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %% [markdown]
# Answer:
#
# For the most part, the test scores do not follow a completely normal distribution. The testing scores show that a good portion of the population is near the average, however a slightly significant amount also score near the top and lowest part of the scale.
#
# For participation, it also shows that it does not follow a normal distribution. This would be due to the fact that there are states with 100% or 0% participation rates for both the SAT and ACT. Though the average is near 40% for SAT and 60 for the ACT, there is no clear normal distribution for both these test in regards to participation.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# Math: As mentioned previously, the scores do not follow a normal distribution. Although there is a average and majority of the scores are near that average, there is a second hump near the 620 point mark for both years. More than 68% of the scores do not fall within 1 standard deviation of the average. Since these distributions do not follow a normal distribution, it would be harder to estimate where exactly would a state fall in terms of averages.
#
# Reading: The reading scores follow the math score distribution. However, the second hump is actually towards a higher end of the scoring scale. This shows that perhaps the students are more comfortable with the reading sections than the math section.
#
# For participation, it also shows that it does not follow a normal distribution. This would be due to the fact that there are a significant amount of states with 100% or 0% participation rates for the SAT. Though the average is near 40% for SAT and 60 for the ACT, there is no clear normal distribution for both these test in regards to participation. Since there is a signfiicant amount of states and both ends of the scale, it will be hard to determine if the average is an accurate representation for students participating in either test.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# It is a good starting point to begin statistical inference. However, if we were to answer the question about participation rates, more data would be needed. Data such as state funding for each test, or contracts between each testing organization and specific states. It is currently not enough to come to any significant conclusion with just the data at hand.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# No, since they are two different tests, with two different scoring schemes the scores are skewed differently. Since the SAT math sections are also separated into two different sections, they put specific emphasis on specific skills needed for each test.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?
